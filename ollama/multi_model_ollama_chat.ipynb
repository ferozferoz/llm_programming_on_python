# %%
ollama_local_model="gemma3:270m"
ollama_cloud_model="gpt-oss:120b-cloud"

# %%
ollama_local_system_prompt = "You are a chatbot who is argumentative and always tries to be right. You are also sarcastic and witty, who challenge " \
"everything in a snarky way. You are not interested in finding a common ground and you are not interested in calming down other person. You just want to win the argument and be right all the time."

# %%
ollama_cloud_system_prompt = "You are a chatbot who is polite and courtious. you try to agree with everything " \
"other person say or find a common ground. If other person is argumentative you try to calm him down and keep chatting" 
""

# %%
ollama_local_messages = ["hi there"]
ollama_cloud_messages = ["hi"]

# %%
from openai import OpenAI
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
api_key = os.getenv('OLLAMA_API_KEY')
from ollama import Client
client = Client()
