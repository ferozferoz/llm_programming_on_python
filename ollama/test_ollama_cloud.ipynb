# %%
import os

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OLLAMA_API_KEY')

# %%
from ollama import Client
client = Client()
messages = [
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
]

for part in client.chat('gpt-oss:120b-cloud', messages=messages, stream=True):
  print(part['message']['content'], end='', flush=True)
# Out:
# **Short answer:**
# The sky looks blue because Earth’s atmosphere scatters short‑wavelength (blue) light from the Sun far more efficiently than it scatters longer‑wavelength (red‑orange) light. Our eyes receive a lot of that scattered blue light from every direction, so the whole dome overhead appears blue.
#
# ---
#
# ## The physics behind it
#
# | Step | What happens | Why it matters |
# |------|---------------|----------------|
# | 1. Sunlight reaches Earth | Sunlight is a mixture of all visible wavelengths (roughly 380 nm – 750 nm). | The light entering the atmosphere is essentially white. |
# | 2. Light encounters molecules and tiny particles | The atmosphere is filled with nitrogen (N₂), oxygen (O₂), and trace gases, plus occasional aerosols. | These particles are **much smaller** than the wavelength of visible light (size ≈ 0.1 µm). |
# | 3. Rayleigh scattering | When light hits particles much smaller than its wavelength, the scattering intensity follows **∝ 1/λ⁴** (the inverse‑fourth‑power law). | Shorter wavelengths (blue, ~450 nm) are scattered ~10 × more strongly than longer wavelengths (red, ~650 nm). |
# | 4. Scattered light reaches your eyes | Blue photons are redirected in many directions, filling the sky overhead with diffuse blue light. | You see the sky as a bright, relatively uniform blue because the blue component dominates the scattered light that reaches you. |
# | 5. Direct (unscattered) sunlight | Light that travels straight from the Sun to your eye suffers little scattering, so it remains white (or slightly yellow). | This is why the Sun itself isn’t blue even though the surrounding sky is. |
#
# ### Rayleigh scattering formula (simplified)
#
# \[
# I_{\text{scattered}}(\lambda) \; \propto \; \frac{1}{\lambda^{4}} \; N \; \alpha^{2}
# \]
#
# * \(I_{\text{scattered}}(\lambda)\): intensity of scattered light at wavelength \(\lambda\)
# * \(N\): number density of scatterers (air molecules)
# * \(\alpha\): polarizability of the molecules (how easily their electron cloud is distorted)
#
# Because \(\lambda\) appears in the denominator to the fourth power, halving the wavelength (e.g., from 600 nm red to 300 nm UV) boosts scattering by 16×. Visible blue (≈450 nm) ends up being scattered roughly **10 times more** than green (≈550 nm) and **~30 times more** than red (≈650 nm).
#
# ---
#
# ## Why the sky isn’t violet even though violet scatters even more
#
# * Human eyes are **less sensitive** to violet light (the photopic sensitivity curve peaks in the green).
# * A lot of violet light is **absorbed** by the upper atmosphere (ozone).
# * The scattered violet mixes with the scattered blue, and our brain interprets the combination as “blue.”
#
# ---
#
# ## Changing colors at sunrise, sunset, and in polluted air
#
# | Situation | What changes | Resulting sky color |
# |-----------|--------------|---------------------|
# | **Sun near the horizon** (sunrise/sunset) | Sunlight must travel through **much more atmosphere** → more scattering of blue light out of the line of sight; longer wavelengths survive. | **Red, orange, pink** hues dominate. |
# | **Aerosols, dust, or water droplets** (e.g., after a volcanic eruption or in haze) | Particles become comparable in size to the wavelength → **Mie scattering** (∝ 1/λ, not 1/λ⁴). | Scattering becomes less wavelength‑selective, giving a **whitish or milky** sky and more vivid reds at sunset. |
# | **Clouds** | Water droplets are large (≈10 µm) → strong, broadband scattering. | Clouds appear **white** (all colors mixed). |
# | **Airglow & night sky** | No direct Sunlight; emission from atoms (e.g., O, Na) and scattering of starlight. | Night sky is dark with faint **green** (oxygen) and **red** (sodium) auroral/airglow lines. |
#
# ---
#
# ## Quick mental model
#
# 1. **Sunlight → white** (mix of all colors).
# 2. **Atmosphere = sea of tiny scatterers** → preferentially throws blue light sideways.
# 3. **Your eyes look up → they receive that sideways‑scattered blue all around.**
#
# Hence, the dome overhead appears blue. When the Sun is low, the path through the atmosphere is long, the blue is scattered out of the line of sight, and the remaining reds give the spectacular sunrise/sunset colors we love.
#
# ---
#
# ### TL;DR
#
# *Blue sky = Rayleigh scattering of short‑wavelength light by tiny air molecules; blue light is scattered ≈10× more than red, fills the sky, and our eyes are most responsive to it.*
